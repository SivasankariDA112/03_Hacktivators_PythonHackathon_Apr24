# %%
import pandas as pd
import numpy as np
import datetime

# %%
df0 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=0)
df1 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=1)
df2 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=2)
df3 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=3)
df4 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=4)
df5 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=5)
df6 = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=6)

# %%
df2 = df[df["type_of_heart_failure"] == "Both"]

# %%
both_count = len(df2)
both_count
# Out:
# 1480

# %%
total_count = len(df)
total_count
# Out:
# 2008

# %%
percentage = (both_count/total_count)*100
percentage
# Out:
# 73.70517928286853

# %%
temp = df['dischargeDay'].apply(np.ceil).apply(lambda x: pd.Timedelta(x, unit='D'))
temp
# Out:
# 0      11 days
# 1       8 days
# 2       5 days
# 3      11 days
# 4       5 days
#          ...
# 2003    5 days
# 2004    8 days
# 2005   14 days
# 2006    1 days
# 2007    6 days
# Name: dischargeDay, Length: 2008, dtype: timedelta64[ns]

# %%
df['Discharge_date'] = df['Admission_date'] + temp

# %%
df['Discharge_date']
# Out:
# 0      2017-02-04
# 1      2017-05-13
# 2      2016-11-23
# 3      2017-10-13
# 4      2019-11-22
#           ...
# 2003   2016-02-12
# 2004   2017-04-06
# 2005   2018-02-05
# 2006   2019-11-28
# 2007   2017-02-23
# Name: Discharge_date, Length: 2008, dtype: datetime64[ns]

# %%
severe=(df.loc[df['GCS'].isin([3,4,5,6,7,8])])
severe
severe_count = len(severe)
severe_count
# Out:
# 19

# %%
moderate=(df.loc[df['GCS'].isin([9,10,11,12])])
moderate
moderate_count = len(moderate)
moderate_count
# Out:
# 29

# %%
mild=(df.loc[df['GCS'].isin([13,14,15])])
mild_count = len(mild)
mild_count
# Out:
# 1960

# %%
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name=2)

# Plot a histogram of a single column in the DataFrame
df.hist(column='GCS')

# Set the title and axis labels
plt.title('Histogram of GCS')
plt.xlabel('Values')
plt.ylabel('Frequency')

# Display the histogram
plt.show()

# %%
df.loc[:,'type_of_heart_failure']
# Out:
# 0       Both
# 1       Both
# 2       Both
# 3       Both
# 4       Both
#         ...
# 2003    Both
# 2004    Both
# 2005    Both
# 2006    Both
# 2007    Left
# Name: type_of_heart_failure, Length: 2008, dtype: object

# %% [markdown]
# 21.Given the names and grades for each student in a class of students, store them in a nested list and print the name(s) of any student(s) having the second lowest grade.
# python_students = [['Harry', 37.21], ['Berry', 37.21], ['Tina', 37.2], ['Akriti', 41], ['Harsh', 39]]

# %%
n=int(input())
result=[]
grade=[]
for i in range(n):
    name=input()
    mark=float(input())
    result.append([name,mark])
    grade.append(mark)   #calculation 2nd lowest
#print(result)   
#print(grade)
grade=sorted(set(grade))  #sorted unique
#print(grade)
m=grade[1]
#print(m)
name=[]
for val in result:
    if m==value[1]:
        name.append(value[0])
#print(name)   #unsorted     
name.sort()
#print(name)   #sorted
for nm in name:
    print(nm)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 n=int(input())
#       2 result=[]
#       3 grade=[]
#
# File /opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# ...

# %% [markdown]
# 28.Store patient number and gender in a dictionary as a pair of values. Show the first 10 values

# %%
names = list(df5.inpatient_number)
 gender_identity = list(df5.gender)
person{}
for name in names:
for gender_identity in identity:
person[name]={'name':name,'gender':g}
print{person}
# Out:
#   Cell In[40], line 2
#     gender_identity = list(df5.gender)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# 31.Group the days to re-admission into bins and count how many patients were in each bin

# %%
df0['readmission_time_days_from_admission'].unique
# Out:
# <bound method Series.unique of 0        NaN
# 1        NaN
# 2        NaN
# 3       19.0
# 4        NaN
#         ...
# 2003     NaN
# 2004     NaN
# 2005    76.0
# 2006     NaN
# 2007     NaN
# Name: readmission_time_days_from_admission, Length: 2008, dtype: float64>

# %%
days = df0.loc[:,'readmission_time_days_from_admission'] 
bins = 25
days_bins = pd.cut(days, bins)
print(days_bins)
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3       (-1.279, 92.16]
# 4                   NaN
#              ...
# 2003                NaN
# 2004                NaN
# 2005    (-1.279, 92.16]
# 2006                NaN
# 2007                NaN
# Name: readmission_time_days_from_admission, Length: 2008, dtype: category
# Categories (25, interval[float64, right]): [(-1.279, 92.16] < (92.16, 183.32] < (183.32, 274.48] < (274.48, 365.64] ... (1915.36, 2006.52] < (2006.52, 2097.68] < (2097.68, 2188.84] < (2188.84, 2280.0]]

# %%
days_bins = pd.cut(df0['readmission_time_days_from_admission'],25)
days_bins
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3       (-1.279, 92.16]
# 4                   NaN
#              ...
# 2003                NaN
# 2004                NaN
# 2005    (-1.279, 92.16]
# 2006                NaN
# 2007                NaN
# Name: readmission_time_days_from_admission, Length: 2008, dtype: category
# Categories (25, interval[float64, right]): [(-1.279, 92.16] < (92.16, 183.32] < (183.32, 274.48] < (274.48, 365.64] ... (1915.36, 2006.52] < (2006.52, 2097.68] < (2097.68, 2188.84] < (2188.84, 2280.0]]

# %% [markdown]
# 29.What percentage of those in a coma also have diabetes?

# %%
merge_data = df2.merge(df3)
result = merge_data.loc[(merge_data['diabetes'] == 1) & (merge_data['GCS'] <= 8) ]
result
count1 = len(result)
count1
count2 = len(merge_data)
count2
c = (count1/count2)*100
c
# Out:
# 0.099601593625498

# %%
result = a.loc[(a['diabetes'] == 1) & (a['GCS'] <= 8) ]
result
# Out:
#       inpatient_number  eye_opening  verbal_response  movement  consciousness  \
# 1028            790433            1                1         1  Nonresponsive
# 1111            730841            1                1         1  Nonresponsive
#
#       GCS  cerebrovascular_disease  dementia  \
# 1028    3                        1         0
# 1111    3                        1         0
#
#       Chronic_obstructive_pulmonary_disease  connective_tissue_disease  ...  \
# 1028                                      0                          0  ...
# 1111                                      0                          0  ...
#
#       moderate_to_severe_chronic_kidney_disease  hemiplegia  leukemia  \
# 1028                                        1.0           0         0
# 1111                                        1.0           0         0
#
#       malignant_lymphoma  solid_tumor  liver_disease  AIDS  CCI_score  \
# 1028                   0            0            1.0     0        5.0
# ...

# %%
count1 = len(result)
count1
# Out:
# 2

# %%
count2 = len(a)
count2
# Out:
# 2008

# %%
c = (count1/count2)*100
c
# Out:
# 0.099601593625498

# %%
biventricular= df1[df1["type_of_heart_failure"] == "Both"]
both_count = len(biventricular)
both_count
total_count = len(df1)
total_count
percentage = (both_count/total_count)*100
percentage
# Out:
# 73.70517928286853

# %%
severe=(df2.loc[df2['GCS'].isin([3,4,5,6,7,])])
severe
severe_count = len(severe)
severe_count

moderate=(df2.loc[df2['GCS'].isin([8,9,10,11,12])])
moderate
moderate_count = len(moderate)
moderate_count

mild=(df2.loc[df2['GCS'].isin([13,14,15])])
mild_count = len(mild)
mild_count
# Out:
# 1960

# %%
temp = df0['dischargeDay'].apply(np.ceil).apply(lambda x: pd.Timedelta(x, unit='D'))
temp
df0['Discharge_date'] = df0['Admission_date'] + temp
df0['Discharge_date']

# %% [markdown]
# 77.List the number of cardiogenic shock patients based on hospitalization outcome, having a severe GCS score(higher risk of death

# %%
merge012 = pd.merge(pd.merge(df0,df1,on = 'inpatient_number'),df2,on = 'inpatient_number')
merge012
# Out:
#       inpatient_number DestinationDischarge admission_ward admission_way  \
# 0               857781                 Home     Cardiology  NonEmergency
# 1               743087                 Home     Cardiology  NonEmergency
# 2               866418                 Home     Cardiology  NonEmergency
# 3               775928                 Home     Cardiology     Emergency
# 4               810128                 Home     Cardiology  NonEmergency
# ...                ...                  ...            ...           ...
# 2003            740689   HealthcareFacility    GeneralWard     Emergency
# 2004            734280   HealthcareFacility    GeneralWard     Emergency
# 2005            781004   HealthcareFacility     Cardiology     Emergency
# 2006            744870              Unknown     Cardiology  NonEmergency
# 2007            791864                 Home     Cardiology     Emergency
#
#      discharge_department  visit_times respiratory_support oxygen_inhalation  \
# ...

# %%
pd.merge(df0,df1,on = 'inpatient_number')
# Out:
#       inpatient_number DestinationDischarge admission_ward admission_way  \
# 0               857781                 Home     Cardiology  NonEmergency
# 1               743087                 Home     Cardiology  NonEmergency
# 2               866418                 Home     Cardiology  NonEmergency
# 3               775928                 Home     Cardiology     Emergency
# 4               810128                 Home     Cardiology  NonEmergency
# ...                ...                  ...            ...           ...
# 2003            740689   HealthcareFacility    GeneralWard     Emergency
# 2004            734280   HealthcareFacility    GeneralWard     Emergency
# 2005            781004   HealthcareFacility     Cardiology     Emergency
# 2006            744870              Unknown     Cardiology  NonEmergency
# 2007            791864                 Home     Cardiology     Emergency
#
#      discharge_department  visit_times respiratory_support oxygen_inhalation  \
# ...

# %%
cardiogenic_patients_with_higher_risk_of_death = merge012.loc[ (merge012['Killip_grade'] == 4) & (merge012['GCS'] <= 5) ]
cardiogenic_patients_with_higher_risk_of_death
# Out:
#       inpatient_number DestinationDischarge admission_ward admission_way  \
# 1058            834443                 Home    GeneralWard     Emergency
# 1111            730841              Unknown     Cardiology     Emergency
# 1184            797195                 Home         Others  NonEmergency
# 1207            854580                 Died     Cardiology     Emergency
# 1252            765343                 Died     Cardiology     Emergency
# 1295            835988                 Home     Cardiology  NonEmergency
# 1872            805475                 Died     Cardiology     Emergency
# 1893            859912                 Home    GeneralWard     Emergency
# 1997            750447                 Died     Cardiology  NonEmergency
# 2006            744870              Unknown     Cardiology  NonEmergency
#
#      discharge_department  visit_times respiratory_support oxygen_inhalation  \
# 1058          GeneralWard            3                 NaN     OxygenTherapy
# ...

# %%
cardiogenic_patients_with_higher_risk_of_death.columns
# Out:
# Index(['inpatient_number', 'DestinationDischarge', 'admission_ward',
#        'admission_way', 'discharge_department', 'visit_times',
#        'respiratory_support', 'oxygen_inhalation', 'dischargeDay',
#        'Admission_date', 'outcome_during_hospitalization',
#        'death_within_28_days', 're_admission_within_28_days',
#        'death_within_3_months', 're_admission_within_3_months',
#        'death_within_6_months', 're_admission_within_6_months',
#        'time_of_death__days_from_admission',
#        'readmission_time_days_from_admission',
#        'return_to_emergency_department_within_6_months',
#        'time_to_emergency_department_within_6_months', 'Discharge_date',
#        'NYHA_cardiac_function_classification', 'Killip_grade',
#        'myocardial_infarction', 'congestive_heart_failure',
#        'peripheral_vascular_disease', 'type_of_heart_failure', 'LVEF',
#        'left_ventricular_end_diastolic_diameter_LV', 'mitral_valve_EMS',
# ...

# %%
cardiogenic_patients_with_higher_risk_of_death['outcome_during_hospitalization'].value_counts()
# Out:
# outcome_during_hospitalization
# Dead                     5
# DischargeAgainstOrder    5
# Name: count, dtype: int64

# %%
cardiogenic_patients_with_higher_risk_of_death['GCS'].value_counts().sort_index()
# Out:
# GCS
# 3    9
# 4    1
# Name: count, dtype: int64

# %%
cardiogenic_patients_with_higher_risk_of_death[['outcome_during_hospitalization', 'GCS']]
# Out:
#      outcome_during_hospitalization  GCS
# 1058                           Dead    3
# 1111          DischargeAgainstOrder    3
# 1184          DischargeAgainstOrder    4
# 1207                           Dead    3
# 1252                           Dead    3
# 1295          DischargeAgainstOrder    3
# 1872                           Dead    3
# 1893          DischargeAgainstOrder    3
# 1997                           Dead    3
# 2006          DischargeAgainstOrder    3

# %%
len(cardiogenic_patients_with_higher_risk_of_death)
# Out:
# 10
